# %%
import os
from dotenv import load_dotenv
from huggingface_hub import login
from datasets import load_dataset
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import numpy as np
import random
from pricer.items import Item
from pricer.parser import Parse
load_dotenv(override=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 9
#       7 import numpy as np
#       8 import random
# ----> 9 from pricer.items import Item
#      10 from pricer.parser import Parse
#      11 load_dotenv(override=True)
#
# ModuleNotFoundError: No module named 'pricer.items'

# %%
# Log in to HuggingFace - if you get a "Note" about Environment variable being set, ignore it

hf_token = os.environ['HF_TOKEN']
login(token=hf_token, add_to_git_credential=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Log in to HuggingFace - if you get a "Note" about Environment variable being set, ignore it
# ----> 3 hf_token = os.environ['HF_TOKEN']
#       4 login(token=hf_token, add_to_git_credential=True)
#
# File <frozen os>:685, in __getitem__(self, key)
#
# KeyError: 'HF_TOKEN'

# %% [markdown]
# # Load our dataset

# %% [markdown]
# In the next cell, we load in the dataset from huggingface.
#
# If this gives you an error like "trust_remote_code is no longer supported", then please run this command in a new cell: !uv add --upgrade datasets==3.6.0 and then restart the Kernel, and try again.

# %%
dataset = load_dataset("McAuley-Lab/Amazon-Reviews-2023", "raw_meta_Appliances", split="full", trust_remote_code=True)
# Out:
# README.md: 0.00B [00:00, ?B/s]
# d:\Jeevan\LLM_Engineer\.venv\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\DELL\.cache\huggingface\hub\datasets--McAuley-Lab--Amazon-Reviews-2023. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Amazon-Reviews-2023.py: 0.00B [00:00, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# meta_Appliances.jsonl:   0%|          | 0.00/285M [00:00<?, ?B/s]
# Generating full split: 0 examples [00:00, ? examples/s]

# %%
print(f"number of appliances: {len(dataset)}")
# Out:
# number of appliances: 94327

# %%
dataset[5]
# Out:
# {'main_category': 'Tools & Home Improvement',
#  'title': '1841N030 - Brown Aftermarket Replacement Stove Range Oven Drip Bowl Pan',
#  'average_rating': 4.5,
#  'rating_number': 7,
#  'features': ['This is a Brand New Aftermarket Replacement Drip Bowl Pan',
#   'Top Qualty Aftermarket Replacement Part!'],
#  'description': ['This is a Brand New Aftermarket Replacement Drip Bowl Pan'],
#  'price': 'None',
#  'images': {'hi_res': [None],
#   'large': ['https://m.media-amazon.com/images/I/51HP3jWvtHL._AC_.jpg'],
#   'thumb': ['https://m.media-amazon.com/images/I/51HP3jWvtHL._AC_US75_.jpg'],
#   'variant': ['MAIN']},
#  'videos': {'title': [], 'url': [], 'user_id': []},
#  'store': 'Brown',
#  'categories': ['Appliances',
#   'Parts & Accessories',
#   'Range Parts & Accessories',
#   'Drip Pans'],
#  'details': '{"Manufacturer": "Universal", "Part Number": "1841N030", "Item Weight": "3 ounces", "Product Dimensions": "6 x 6 x 6 inches", "Item model number": "CECOMINOD023154", "Is Discontinued By Manufacturer": "No", "Item Package Quantity": "1", "Batteries Included?": "No", "Best Sellers Rank": {"Tools & Home Improvement": 1181026, "Range Replacement Drip Pans": 613}, "Date First Available": "November 19, 2013"}',
#  'parent_asin': 'B00GS4892I',
#  'bought_together': None,
#  'subtitle': None,
#  'author': None}

# %%
# ehat's the most expensive appliance?

max_price = 0
max_item = None

for datapoint in tqdm(dataset):
    try:
        price = float(datapoint["price"])
        if price > max_price:
            max_item = datapoint
            max_price = price
    except ValueError:
        pass

print(f"The most expensive appliance is {max_item['title']} and costs ${max_price:.2f}")
# Out:
#   0%|          | 0/94327 [00:00<?, ?it/s]
# The most expensive appliance is TurboChef BULLET Rapid Cook Electric Microwave Convection Oven and costs $21095.62

# %%
# Load into Item objects if they have a price range $1-$1000 and enough details

items = [parse(datapoint, "Appliances") for datapoint in tqdm(dataset)]
items = [item for item in items if item is not None]
print(f"number of valid items: {len(items)} from {len(dataset)}")
# Out:
#   0%|          | 0/94327 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 # Load into Item objects if they have a price range $1-$1000 and enough details
# ----> 3 items = [parse(datapoint, "Appliances") for datapoint in tqdm(dataset)]
#       4 items = [item for item in items if item is not None]
#       5 print(f"number of valid items: {len(items)} from {len(dataset)}")
#
# NameError: name 'parse' is not defined

# %%
items[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 items[0]
#
# NameError: name 'items' is not defined

# %%
print(items[0].full)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print(items[0].full)
#
# NameError: name 'items' is not defined

# %%
prices = [item.price for item in items]
lengths = [len(item.full) for item in items]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 prices = [item.price for item in items]
#       2 lengths = [len(item.full) for item in items]
#
# NameError: name 'items' is not defined

# %%
# Plot the distribution of lengths

plt.figure(figsize=(15, 6))
plt.title(f"Lengths: Avg {sum(lengths)/len(lengths):,.0f} and highest {max(lengths):,}\n")
plt.xlabel('Length (chars)')
plt.ylabel('Count')
plt.hist(lengths, rwidth=0.7, color="lightblue", bins=range(0, 6000, 100))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 # Plot the distribution of lengths
#       3 plt.figure(figsize=(15, 6))
# ----> 4 plt.title(f"Lengths: Avg {sum(lengths)/len(lengths):,.0f} and highest {max(lengths):,}\n")
#       5 plt.xlabel('Length (chars)')
#       6 plt.ylabel('Count')
#
# NameError: name 'lengths' is not defined

# %%
max_length = max(lengths)
max_length_item = items[lengths.index(max_length)]
print(max_length_item.full)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 max_length = max(lengths)
#       2 max_length_item = items[lengths.index(max_length)]
#       3 print(max_length_item.full)
#
# NameError: name 'lengths' is not defined

# %%
# Plot the distribution of prices
plt.figure(figsize=(15, 6))
plt.title(f"Prices: Avg {sum(prices)/len(prices):,.2f} and highest {max(prices):,}\n")
plt.xlabel('Price ($)')
plt.ylabel('Count')
plt.hist(prices, rwidth=0.7, color="orange", bins=range(0, 1000, 10))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 # Plot the distribution of prices
#       2 plt.figure(figsize=(15, 6))
# ----> 3 plt.title(f"Prices: Avg {sum(prices)/len(prices):,.2f} and highest {max(prices):,}\n")
#       4 plt.xlabel('Price ($)')
#       5 plt.ylabel('Count')
#
# NameError: name 'prices' is not defined

# %%
print(items[3].full)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print(items[3].full)
#
# NameError: name 'items' is not defined

# %%
from pricer.loaders import ItemLoader
loader = ItemLoader("Appliances")
items = loader.load()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 from pricer.loaders import ItemLoader
#       2 loader = ItemLoader("Appliances")
#       3 items = loader.load()
#
# ModuleNotFoundError: No module named 'pricer.loaders'

# %%
dataset_names = [
    "Automotive",
    "Electronics",
    "Office_Products",
    "Tools_and_Home_Improvement",
    "Cell_Phones_and_Accessories",
    "Toys_and_Games",
    "Appliances",
    "Musical_Instruments",
]
