# %% [markdown]
# # Tokenizing with code

# %%
import tiktoken
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import toktoken
#
# ModuleNotFoundError: No module named 'toktoken'

# %%
encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")

tokens = encoding.encode("Hello, world!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")
#       3 tokens = encoding.encode("Hello, world!")
#
# NameError: name 'tiktoken' is not defined

# %%
tokens

# %%
for token_id in tokens:
    token_text = encoding.decode([token_id])
    print(token_text, end=" ")

# %%
encoding.decode([222])

# %% [markdown]
# # Another topic: The illusion of memory

# %%
import os
from dotenv import load_dotenv

load_dotenv(override=True)

# %%
api_key = os.getenv('OPENAI_API_KEY')

# check the key

if not api_key:
    print("No API key found")
elif not api_key.startswith("sk-proj"):
    print("api key do not start with sk-proj, please check the key")
elif api_key.strip() != api_key:
    print("An API Key was found, but it looks like it might have space or tab characters at the beginning or end., please romove them")
else:
    print("API key found, looks fine so far")

# %%
from openai import OpenAI
openai = OpenAI()

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant that can answer questions and help with tasks."},
    {"role": "user", "content": "What is the capital of the moon?"}
]

# %%
response = openai.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=messages,

# %%
response.choices[0].message.content

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant that can answer questions and help with tasks."},
    {"role": "user", "content": "I am Jeevan, What is the capital of the moon?"},
    {"role": "assistant", "content": "The capital of the moon is the moon."},
    {"role": "user", "content": "What is my name?"}
]

# %% [markdown]
# Every call to LLM is completely STATELESS
